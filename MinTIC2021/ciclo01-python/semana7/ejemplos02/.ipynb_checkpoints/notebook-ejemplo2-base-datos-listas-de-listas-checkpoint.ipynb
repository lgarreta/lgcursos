# %% [markdown]
# # Ejemplo2 Base Datos Estudiantes con Listas de Lista

# %%
# Ejemplo programa con menu
## FUNCIONES
def buscarPorNombre (listaUsuarios):
    #nombreBuscar = input ("NOMBRE:")
    #while (....):
    #    nombre = ...
    #    if (nombre == nombreBuscar):
    #        ....
            
    #....
    print ("Aun no implementada")
    
def borrarUsuario (listaUsuarios):
    # cedulaBorrar = input ("CEDULA")
    # listaEstudiantesNueva = []
    # while (...):
    #   cedula = ...
    #   if (cedulaBorrar == cedula):
    #       None
    #   else:
    #       listaEstudiantesNueva.append (usuario)
    # #
    # listaUsuarios = listaEstudiantesNueva
    print ("Aun no implementada")
    
def adicionarUsuario (listaUsuarios):
    nombre   = input ("NOMBRE: ")
    cedula   = input ("CEDULA: ")
    celular  = input ("CELULAR")
    
    usuario  = [nombre, cedula, celular]
    listaUsuarios.append (usuario)
#

    
def imprimirLista (lista):
    N = len (lista)
    i = 0
    while (i < N):
        usuario = lista [i]
        nombre   = usuario [0]
        cedula   = usuario [1]
        telefono = usuario [2]
        # Proceso
        
        print (nombre)
        print (cedula
        print (telefono)
        i+=1
    #
#   
        

def verFiltrados (listaUsuarios):
    #...
    #...
    #...
    #listaFiltrados
    imprimirLista (listaFiltrados)
    

## PRINCIPAL  
listaUsuarios = []
while (True):
    print (">>>>>>>>>>> OPCIONES <<<<<<<<<<<<<<<<<<")
    print ("0. Salir")
    print ("1. Buscar por nombre")
    print ("2. Borrar")
    print ("3. Adicionar")
    print ("4. Imprimir")
    print (">>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<")
    
    opcion = int (input ("Ingrese la opción"))
    
    if (opcion==0):
        break
    elif (opcion==1):
        buscarPorNombre ()
    elif (opcion==2):
        borrarUsuario()
    elif (opcion==3):
        adicionarUsuario (listaUsuarios)
    elif (opcion==4):
        imprimirLista (listaUsuarios)
    else:
        print ("Opción no valida")
    #
    print ()
#
print ()
print ("Adios")
# Out:
# >>>>>>>>>>> OPCIONES <<<<<<<<<<<<<<<<<<
# 0. Salir
# 1. Buscar por nombre
# 2. Borrar
# 3. Adicionar
# 4. Imprimir
# >>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<
# Ingrese la opción4
#
# >>>>>>>>>>> OPCIONES <<<<<<<<<<<<<<<<<<
# 0. Salir
# 1. Buscar por nombre
# 2. Borrar
# 3. Adicionar
# 4. Imprimir
# >>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<
# Ingrese la opción3
# NOMBRE: ana
# CEDULA: 1010
# CELULAR310
#
# >>>>>>>>>>> OPCIONES <<<<<<<<<<<<<<<<<<
# 0. Salir
# 1. Buscar por nombre
# 2. Borrar
# 3. Adicionar
# 4. Imprimir
# >>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<
# Ingrese la opción4
# ana
# 1010
# 310
#
# >>>>>>>>>>> OPCIONES <<<<<<<<<<<<<<<<<<
# 0. Salir
# 1. Buscar por nombre
# 2. Borrar
# 3. Adicionar
# 4. Imprimir
# >>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<
# Ingrese la opción3
# NOMBRE: maria
# CEDULA: 2020
# CELULAR320
#
# >>>>>>>>>>> OPCIONES <<<<<<<<<<<<<<<<<<
# 0. Salir
# 1. Buscar por nombre
# 2. Borrar
# 3. Adicionar
# 4. Imprimir
# >>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<
# ...
